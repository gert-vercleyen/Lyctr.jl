# %%
using Oscar

# %%
Qx, x = QQ["x"];
K,a = number_field([x^2-2,x^3+x+1],"a")
# Out:
# (Non-simple number field of degree 6 over QQ, AbsNonSimpleNumFieldElem[a1, a2])

# %%
typeof(K)
# Out:
# AbsNonSimpleNumField

# %%
typeof(K)
# Out:
# AbsNonSimpleNumField

# %%
supertype(supertype(supertype(supertype(typeof(K)))))
# Out:
# Ring
